# %% [markdown]
# # Dataset Exploration
# In this notebook, we explore the 75 time series segmentation datasets.

# %%
import numpy as np

import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 26})

import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import sys

sys.path.append("../../")

# %%
from tssb.utils import load_time_series_segmentation_datasets, visualize_time_series

# %% [markdown]
# Let's load and list the datasets.

# %%
df_ts = load_time_series_segmentation_datasets()
df_ts
# Out:
#                            dataset  window_size  \
# 0                            Adiac           10
# 1                        ArrowHead           10
# 2                             Beef           50
# 3                        BeetleFly           10
# 4                      BirdChicken           20
# 5                              Car           20
# 6                              CBF           20
# 7                        Chinatown           10
# 8            ChlorineConcentration           10
# 9                     CinCECGTorso           10
# 10                          Coffee           10
# 11                       Computers           50
# 12                        CricketX           10
# 13                        CricketY           10
# 14                        CricketZ           10
# 15                            Crop           10
# 16             DiatomSizeReduction           20
# 17    DistalPhalanxOutlineAgeGroup           50
# 18                 DistalPhalanxTW           10
# 19                   DodgerLoopDay           20
# 20                          ECG200           20
# 21                     ECGFiveDays           20
# 22             EOGHorizontalSignal           20
# 23               EOGVerticalSignal           20
# 24                         FaceAll           10
# 25                        FaceFour           50
# 26                        FacesUCR           20
# 27                      FiftyWords           10
# 28                            Fish           10
# 29             FreezerRegularTrain           20
# 30                             Ham           10
# 31                         Herring           10
# 32                        GunPoint           10
# 33                         Haptics           10
# 34                     InlineSkate           10
# 35             InsectWingbeatSound           10
# 36                ItalyPowerDemand           20
# 37          LargeKitchenAppliances          100
# 38                      Lightning2           20
# 39                      Lightning7           50
# 40                          Mallat           10
# 41                            Meat           10
# 42                   MedicalImages           10
# 43             MelbournePedestrian           10
# 44    MiddlePhalanxOutlineAgeGroup           10
# 45     MiddlePhalanxOutlineCorrect           10
# 46                 MiddlePhalanxTW           10
# 47                      MoteStrain           50
# 48      NonInvasiveFetalECGThorax1           20
# 49      NonInvasiveFetalECGThorax2           20
# 50                        OliveOil           50
# 51                         OSULeaf           10
# 52                           Plane           10
# 53  ProximalPhalanxOutlineAgeGroup           10
# 54   ProximalPhalanxOutlineCorrect           10
# 55               ProximalPhalanxTW           10
# 56                       ShapesAll           10
# 57                     ShapeletSim           50
# 58           SonyAIBORobotSurface1           20
# 59           SonyAIBORobotSurface2           10
# 60                      Strawberry           10
# 61                     SwedishLeaf           10
# 62                         Symbols           10
# 63                SyntheticControl           10
# 64                ToeSegmentation1           10
# 65                ToeSegmentation2           10
# 66                           Trace           50
# 67                      TwoLeadECG           10
# 68                             UMD           10
# 69          UWaveGestureLibraryAll           10
# 70            UWaveGestureLibraryX           10
# 71            UWaveGestureLibraryY           10
# 72            UWaveGestureLibraryZ           10
# 73                    WordSynonyms           10
# 74                            Yoga           10
#
#                                         change_points  \
# 0                                   [572, 1012, 1232]
# 1                                               [753]
# 2                                               [705]
# 3                                              [1280]
# 4                                              [1280]
# 5                                   [577, 1154, 1550]
# 6                                          [384, 704]
# 7                                                  []
# 8                                              [2365]
# 9                                        [2663, 5121]
# 10                                              [500]
# 11                                             [5625]
# 12                            [712, 1293, 1930, 2586]
# 13                            [525, 1162, 1837, 2399]
# 14                            [600, 1106, 1574, 2174]
# 15  [1725, 3450, 5175, 8625, 12075, 15525, 17250, ...
# 16                                         [517, 948]
# 17                                              [300]
# 18                                        [580, 2220]
# 19                                                 []
# 20                                              [744]
# 21                                              [476]
# 22                                 [1406, 2812, 4218]
# 23                     [1406, 2812, 3749, 5155, 6608]
# 24               [1310, 2620, 3930, 5240, 6550, 7860]
# 25                                 [2800, 5600, 6650]
# 26                [851, 1637, 2292, 3733, 4715, 5566]
# 27                                 [1755, 3408, 4521]
# 28               [1504, 2950, 4570, 5785, 7058, 8504]
# 29                                 [2257, 4514, 7900]
# 30                                 [1400, 2935, 4335]
# 31                                                 []
# 32                                              [900]
# 33                                       [1228, 3548]
# 34                                       [1058, 2704]
# 35                                    [320, 640, 960]
# 36                                              [816]
# 37                                       [2812, 5624]
# 38                                              [398]
# 39                           [1276, 2552, 3828, 5742]
# 40                                  [768, 1792, 2560]
# 41                                       [1120, 2240]
# 42                                             [1732]
# 43                [576, 1152, 2016, 2592, 3168, 4032]
# 44                            [880, 2608, 6400, 7720]
# 45                                 [1060, 3000, 4060]
# 46                                                 []
# 47                                              [840]
# 48                    [1687, 4124, 6233, 8108, 10358]
# 49             [1687, 4124, 6233, 8108, 10358, 12420]
# 50                                       [1425, 3705]
# 51                                        [907, 1680]
# 52                [540, 1044, 1368, 1944, 2412, 3060]
# 53                                        [720, 2110]
# 54                                  [776, 3212, 4376]
# 55                                  [320, 2500, 3660]
# 56                           [1280, 2560, 3840, 5120]
# 57                                                 []
# 58                                              [420]
# 59                                              [715]
# 60                                  [804, 2250, 3054]
# 61                                  [928, 2080, 3200]
# 62                                  [796, 1293, 1591]
# 63                            [750, 1500, 2250, 3000]
# 64                                             [1385]
# 65                                             [1543]
# 66                                       [1443, 2955]
# 67                                              [246]
# 68                                                 []
# 69                           [1801, 3395, 4960, 6584]
# 70                            [600, 1131, 1652, 2193]
# 71                            [600, 1131, 1652, 2193]
# 72                            [600, 1131, 1652, 2193]
# 73                                        [202, 2227]
# 74                                             [7295]
#
#                                           time_series
# 0   [1.681146, 1.383394, 1.029389, 0.688386, 0.354...
# 1   [-1.957721, -1.858082, -1.657983, -1.420794, -...
# 2   [-0.380818, -0.352238, -0.295392, -0.225041, -...
# 3   [1.114805, 0.774403, 0.477129, 0.115781, -0.24...
# 4   [1.697714, 1.439032, 1.22287, 0.99708, 0.76479...
# 5   [1.451648, 1.030174, 0.531853, 0.040229, -0.40...
# 6   [-1.27713, -0.689811, -0.901181, -0.937038, -0...
# 7   [0.025935, -0.435655, -0.608168, -0.81565, -1....
# 8   [2.496227, 1.046743, 0.391124, 0.607525, -0.22...
# 9   [-0.118215, -0.115326, -0.111855, -0.1229, -0....
# 10  [-0.644379, -0.935444, -0.98246, -1.069437, -0...
# 11  [-0.335265, -0.335265, -0.335265, -0.335265, -...
# 12  [1.668728, 1.811384, 0.156194, 1.085055, 0.154...
# 13  [-0.074266, 0.125085, -2.299074, 0.691614, 0.2...
# 14  [0.538865, -0.236127, -0.773805, 0.690791, 0.2...
# 15  [-1.019125, -0.935957, -0.830774, -0.742103, -...
# 16  [1.851103, 1.750701, 1.542724, 1.312404, 1.078...
# 17  [-0.095842, 1.327276, 0.384633, -0.255218, 1.4...
# 18  [-0.733757, 0.450916, 1.312294, 1.238173, 0.14...
# 19  [-0.417828, 0.216067, -0.523477, -0.523477, 0....
# 20  [0.803065, 1.965973, 0.145364, -0.268573, -0.3...
# 21  [0.002083, -0.023487, -0.056923, -0.068725, -0...
# 22  [-0.953623, -0.970089, -0.971874, -0.978193, -...
# 23  [1.182717, 1.156045, 1.14153, 1.128699, 1.0830...
# 24  [-0.561392, -1.356218, -0.597665, 1.486103, 1....
# 25  [2.584316, 2.584316, 1.933222, 1.933222, 1.451...
# 26  [-0.363261, -0.229436, -0.477039, -0.591405, -...
# 27  [-0.344551, 1.471721, 2.243461, 1.331494, 0.23...
# 28  [1.871099, 1.540319, 1.203093, 0.870156, 0.538...
# 29  [-2.213755, -2.213911, -2.213822, -2.213715, -...
# 30  [-0.622601, -0.699322, -0.699322, -0.717133, -...
# 31  [1.90136, 1.78353, 1.59648, 1.369286, 1.158101...
# 32  [-0.780473, -0.771591, -0.767739, -0.779923, -...
# 33  [-1.265867, -1.384182, -1.313314, -1.106834, -...
# 34  [-0.382758, -0.397053, -0.445415, -0.507809, -...
# 35  [-0.215131, -0.261711, -0.37249, -0.365237, 0....
# 36  [-0.725799, -1.208771, -1.40196, -1.627347, -1...
# 37  [-0.099177, -0.099177, -0.099177, -0.099177, -...
# 38  [-1.397102, -1.397102, -1.397102, -0.568111, 0...
# 39  [-0.767359, -0.767359, -0.767359, -0.767359, -...
# 40  [-1.023485, -1.066698, -1.125013, -1.146245, -...
# 41  [-0.262821, -0.252491, -0.189973, -0.152557, -...
# 42  [0.433827, 1.651277, 1.535373, 2.368258, 2.465...
# 43  [-1.064676, -1.117918, -1.109614, -0.871247, -...
# 44  [-0.428531, -0.192123, 0.278944, 0.76281, 1.12...
# 45  [-0.505896, 0.411131, 1.32881, 1.356801, 0.464...
# 46  [-0.744506, -0.690583, -0.55563, -0.29238, 0.0...
# 47  [0.082191, 0.057926, 0.019425, -0.018106, -0.0...
# 48  [1.261311, -3.252779, -1.038552, -0.038799, -0...
# 49  [2.740294, -2.153493, -1.492175, -0.381289, -0...
# 50  [-0.611517, -0.604375, -0.590556, -0.574301, -...
# 51  [0.821318, -0.356788, 0.745552, -0.117068, -0....
# 52  [2.195044, 1.409444, 0.570219, -0.17921, -0.87...
# 53  [0.012882, 1.36955, -0.034655, 0.157485, 1.561...
# 54  [-0.017122, 1.378256, -0.041994, 0.151372, 1.5...
# 55  [-0.484701, 0.513983, 1.386599, 1.248457, 0.44...
# 56  [1.512684, 1.320183, 1.136966, 0.960463, 0.786...
# 57  [-0.328954, 0.449697, -0.69761, -0.775463, -0....
# 58  [-0.061214, -0.346881, 1.938453, 3.652453, 1.9...
# 59  [-0.69684, 0.03766, 0.282493, 0.282493, 0.5273...
# 60  [-0.363221, 0.488277, 2.717473, 1.375118, 0.10...
# 61  [1.614456, 0.593546, -0.025966, -0.24674, -0.4...
# 62  [-1.803832, -1.734096, -1.661634, -1.583883, -...
# 63  [0.383272, -0.327715, 0.282826, 1.086384, -0.4...
# 64  [2.013115, 2.191178, 1.511739, 0.470604, 0.011...
# 65  [-0.58341, -0.975442, -1.224916, -0.935348, -0...
# 66  [0.701659, 0.721624, 0.722078, 0.720484, 0.749...
# 67  [-0.071385, 0.117643, 0.155448, -0.011526, -0....
# 68  [0.493984, 0.464761, 0.461762, 0.383778, 0.411...
# 69  [-0.889752, 0.713683, 0.863088, -0.554829, -0....
# 70  [-0.889766, 0.722005, 0.869297, -0.553167, -0....
# 71  [-1.523467, -0.106794, 0.190361, 0.979247, 0.3...
# 72  [-0.527058, 0.416111, -0.524027, 0.41141, 0.12...
# 73  [-1.183581, -0.514028, -0.480539, -0.394855, -...
# 74  [-0.155803, -0.33899, -0.564977, -0.667323, -0...

# %% [markdown]
# Let's visualize by time series length, amount of change points and window size.

# %%
names = df_ts.dataset.to_numpy().tolist()

for idx, name in enumerate(names):
    if name == "PigInternalBleedingDatasetAirwayPressure":
        names[idx] = "PigAirwayPressure"

    if name == "PigInternalBleedingDatasetArtPressureFluidFilled":
        names[idx] = "PigFluidFilled"

    if name == "PigInternalBleedingDatasetCVP":
        names[idx] = "PigCVP"

    if name == "ChlorineConcentration":
        names[idx] = "Chlorine"

    if name == "DiatomSizeReduction":
        names[idx] = "DiatomSize"

    if name == "DistalPhalanxOutlineAgeGroup":
        names[idx] = "DistalPhalanx"

    if name == "InsectWingbeatSound":
        names[idx] = "InsectWingbeat"

    if name == "LargeKitchenAppliances":
        names[idx] = "LargeKitchen"

    if name == "NonInvasiveFetalECGThorax1":
        names[idx] = "ECGThorax1"

    if name == "NonInvasiveFetalECGThorax2":
        names[idx] = "ECGThorax2"

    if name == "ProximalPhalanxOutlineAgeGroup":
        names[idx] = "ProximalPhalanx"

names = np.array(names)

# %%
fontsize = 18

idx_sizes = np.argsort(df_ts.time_series.apply(len)).to_numpy()
_, ax = plt.subplots(1, figsize=(20, 5))
ax.scatter(np.arange(df_ts.shape[0]), df_ts.time_series.apply(len).to_numpy()[idx_sizes])
ax.set_ylabel("time series length", fontsize=20)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.xticks(range(df_ts.shape[0]), names[idx_sizes], rotation=45, ha="right", fontsize=8)

plt.show()
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/2306195934.py:9: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/2306195934.py:12: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)

# %%
fontsize = 18

change_points, counts = np.unique(df_ts.change_points.apply(len), return_counts=True)
_, ax = plt.subplots(1, figsize=(20, 5))
ax.bar(change_points, counts, width=.5)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

ax.set_xlabel("amount of change points", fontsize=20)
ax.set_ylabel("amount of time series", fontsize=20)

plt.show()
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/4166210232.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/4166210232.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)

# %%
fontsize = 18

idx_sizes = np.argsort(df_ts.window_size.to_numpy())
_, ax = plt.subplots(1, figsize=(20, 5))
ax.scatter(np.arange(df_ts.shape[0]), df_ts.window_size.to_numpy()[idx_sizes])
ax.set_ylabel("window size", fontsize=20)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.xticks(range(df_ts.shape[0]), names[idx_sizes], rotation=45, ha="right", fontsize=8)

plt.show()
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/3775367879.py:9: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4999/3775367879.py:12: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)

# %% [markdown]
# Now, let's visually inspect specific instances of time series.

# %%
selection = 15
row = df_ts.iloc[selection, :]

fig, ax = visualize_time_series(row.time_series, row.dataset, row.change_points)
plt.show()
